# %% [markdown]
# # Social Media Sentiment Analysis using TextBlob

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from textblob import TextBlob

# %%
df = pd.read_csv('social_media_data.csv')
df.head()
# Out:
#          date                                               text  \
# 0  2025-01-01  I love the new product launch! So innovative a...
# 1  2025-01-02  The service was terrible, I'm never coming bac...
# 2  2025-01-03  Wow, what a great experience, highly recommend...
# 3  2025-01-04  Totally not worth the money. Very dissatisfied...
# 4  2025-01-05  Fantastic event! Well organized and lots of fu...
#
#                                           clean_text sentiment
# 0  i love the new product launch so innovative an...  positive
# 1  the service was terrible im never coming back ...  negative
# 2  wow what a great experience highly recommend t...  positive
# 3  totally not worth the money very dissatisfied ...   neutral
# 4  fantastic event well organized and lots of fun...  positive

# %% [markdown]
# ## Sentiment Distribution

# %%
sns.countplot(data=df, x='sentiment', palette='Set2')
plt.title('Sentiment Distribution')
plt.show()
# Out:
# C:\Users\Jayesh\AppData\Local\Temp\ipykernel_23284\130235687.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='sentiment', palette='Set2')

# %% [markdown]
# ## Word Cloud

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(df['clean_text']))
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
